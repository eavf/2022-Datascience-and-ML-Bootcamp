# %%
import pandas as pd
from pandas import DataFrame as df
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('.\\static\\lsd_math_score_data.csv')
print (data)
# Out:
#    Time_Delay_in_Minutes  LSD_ppm  Avg_Math_Test_Score
# 0                      5     1.17                78.93
# 1                     15     2.97                58.20
# 2                     30     3.26                67.47
# 3                     60     4.69                37.47
# 4                    120     5.83                45.65
# 5                    240     6.00                32.92
# 6                    480     6.41                29.97

# %%
time = data['Time_Delay_in_Minutes']
lsd = data['LSD_ppm']
score = data['Avg_Math_Test_Score']
print(time)
# Out:
# 0      5
# 1     15
# 2     30
# 3     60
# 4    120
# 5    240
# 6    480
# Name: Time_Delay_in_Minutes, dtype: int64

# %%
plt.title('Tissue concentration of LSD over time', fontsize=17)

plt.xlabel('Time in minutes', fontsize=14)
plt.ylabel('Tissue LSD ppm', fontsize=14)
plt.text(x = 0, y = -0.2, s = 'Vovo and al. (1971)', fontsize=12)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.ylim(1,7)
plt.xlim(0,500)


plt.plot (time, lsd, color='g', linewidth=3)
plt.show()

# %%
plt.plot (time, lsd, color='#c0392b', linewidth=3)
plt.show()

# %%
# https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html
# http://tonysyu.github.io/raw_content/matplotlib-style-gallery/gallery.html

# %%
# This line of code is jupyter specific...
# I exports graph alongside with notebook when we type File->Download as -> notebook
# %matplotlib inline


plt.title('Tissue concentration of LSD over time', fontsize=17)

plt.xlabel('Time in minutes', fontsize=14)
plt.ylabel('Tissue LSD ppm', fontsize=14)
plt.text(x = 0, y = -0.2, s = 'Vovo and al. (1971)', fontsize=12)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.ylim(1,7)
plt.xlim(0,500)

plt.style.use('classic')

plt.plot (time, lsd, color='g', linewidth=3)
plt.show()
